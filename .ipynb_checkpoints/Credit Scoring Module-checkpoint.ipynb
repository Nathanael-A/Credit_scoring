# %% [markdown]
# ## INTRODUCTION
# Name: Nathanael Ayirebaje Azuponga
# Email: azuponganathanael@gmail.com / naazuponga@st.ug.edu.gh
#
# I got my data(Loan_Train) from Kaggle.com
#
# The problem is a classification problem so i will make use of algorithms under classification
#
# 1. I have to load my data, visualize and understand it
#
# 2. I have to clean the data to make it suitable for training the models
#
# 3. Select the best model for the problem and evaluate it
#
# 4. Improve the model
#
# 5. Save the model for future use

# %%
# importing standard 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading and understanding the data 
loan_data = pd.read_csv('Loan_Train.csv')
loan_data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan_data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan_data.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
loan_data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
sns.heatmap(loan_data.isnull(), yticklabels=False,cbar=False, cmap='viridis');

# %%
loan_data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.countplot(x='Gender',data=loan_data);

# %%
sns.countplot(x='Married',data=loan_data);

# %%
sns.countplot(x='Education',hue='Gender',data=loan_data);

# %%
sns.countplot(x='Self_Employed',hue='Gender',data=loan_data);

# %% [markdown]
# ## Cleaning and processing our data

# %%
loan_data.drop('Loan_ID',axis=1,inplace=True)

# %%
loan_data
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
from scipy.stats import mode

# %%
print(mode(loan_data['Gender']).mode[0])
print(mode(loan_data['Married']).mode[0])
# Out:
# Male
# Yes

# %%
loan_data['Gender'].fillna(mode(loan_data['Gender']).mode[0], inplace=True)
loan_data['Married'].fillna(mode(loan_data['Married']).mode[0], inplace=True)
loan_data['Self_Employed'].fillna(mode(loan_data['Self_Employed']).mode[0], inplace=True)

# %%
sns.heatmap(loan_data.isnull(), yticklabels=False,cbar=False, cmap='viridis');

# %%
loan_data
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
loan_data.dropna(inplace=True)

# %%
sns.heatmap(loan_data.isnull(), yticklabels=False,cbar=False, cmap='viridis');

# %%
# Turn the categories into numbers
loan_encoded = pd.get_dummies(loan_data,drop_first=True)

# %%
loan_encoded
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History  Gender_Male  Married_Yes  Dependents_1  Dependents_2  \
# ...

# %% [markdown]
# ## Splitting and training the data

# %%
from sklearn.model_selection import train_test_split
X = loan_encoded.drop('Loan_Status_Y',axis=1)
y = loan_encoded['Loan_Status_Y']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,stratify =y,random_state =42)

# %% [markdown]
# ## This is a classification problem so you choose a model in it.
#
# ## Model 1: Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,f1_score
from sklearn.metrics import confusion_matrix, classification_report

# %%
tree_clf = DecisionTreeClassifier()
tree_clf.fit(X_train,y_train)
y_pred = tree_clf.predict(X_test)
print("Test Accuracy: ",accuracy_score(y_test,y_pred))
print("Test F1 Score: ",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print("Confusion Matrix on Test Data")
pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Test Accuracy:  0.6987179487179487
# Test F1 Score:  0.7751196172248804
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.54        47
#            1       0.81      0.74      0.78       109
#
#     accuracy                           0.70       156
#    macro avg       0.66      0.67      0.66       156
# weighted avg       0.72      0.70      0.71       156
#
# Confusion Matrix on Test Data
# Predicted   0    1  All
# True
# 0          28   19   47
# 1          28   81  109
# All        56  100  156

# %% [markdown]
# ## Model 2: Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf_clf.predict(X_test)
print("Test Accuracy: ",accuracy_score(y_test,y_pred))
print("Test F1 Score: ",f1_score(y_test,y_pred))
print("Confusion Matrix on Test Data")
print(classification_report(y_test,y_pred))
pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Test Accuracy:  0.8461538461538461
# Test F1 Score:  0.8983050847457626
# Confusion Matrix on Test Data
#               precision    recall  f1-score   support
#
#            0       0.90      0.55      0.68        47
#            1       0.83      0.97      0.90       109
#
#     accuracy                           0.85       156
#    macro avg       0.87      0.76      0.79       156
# weighted avg       0.85      0.85      0.83       156
# Predicted   0    1  All
# True
# 0          26   21   47
# 1           3  106  109
# All        29  127  156

# %% [markdown]
# ## Model 3: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_predict

# %%
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test)
print("Test Accuracy: ",accuracy_score(y_test,y_pred))
print("Test F1 Score: ",f1_score(y_test,y_pred))
print("Confusion Matrix on Test Data")
pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Test Accuracy:  0.8269230769230769
# Test F1 Score:  0.8870292887029289
# Confusion Matrix on Test Data
# Predicted   0    1  All
# True
# 0          23   24   47
# 1           3  106  109
# All        26  130  156

# %% [markdown]
# ## Deduction
# Among the three models used random forest classifier performs better, so i will then try to improve his performance by tuning its hyperparameters

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV

grid = {"n_estimators": [10, 100, 200, 500, 1000, 1200],
        "max_depth": [None, 5, 10, 20, 30],
        "max_features": ["auto", "sqrt"],
        "min_samples_split": [2, 4, 6],
        "min_samples_leaf": [1, 2, 4]}

np.random.seed(42)

# %%
clf = RandomForestClassifier(n_jobs=1)
rs_clf = RandomizedSearchCV(estimator=clf,
                            param_distributions=grid, 
                            n_iter=10, # number of models to try
                            cv=5,
                            verbose=2)

# %%
rs_clf.fit(X_train, y_train);
rs_y_preds = rs_clf.predict(X_test)

# %%
print("Test Accuracy: ",accuracy_score(y_test,rs_y_preds))
print("Test F1 Score: ",f1_score(y_test,rs_y_preds))
print("Confusion Matrix on Test Data")
pd.crosstab(y_test, rs_y_preds, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Test Accuracy:  0.8397435897435898
# Test F1 Score:  0.8936170212765958
# Confusion Matrix on Test Data
# Predicted   0    1  All
# True
# 0          26   21   47
# 1           4  105  109
# All        30  126  156

# %% [markdown]
# ## Saving the best model

# %%
import pickle

pickle.dump(rs_clf, open('Credit_Scoring_model', 'wb'))
